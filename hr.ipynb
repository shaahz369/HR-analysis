# %%
import pandas as pd
df=pd.read_csv("HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
df.groupby(df.Department)

# %%
y=df.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
plt.bar(df.satisfaction_level,df.left)
plt.show()

# %%
plt.plot(df.satisfaction_level,df.left)

# %%
dummy=pd.get_dummies(df["salary"],dtype=int)
dummy
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
latest=pd.concat([df,dummy])
latest
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53             2.0
# 1                    0.80             0.86             5.0
# 2                    0.11             0.88             7.0
# 3                    0.72             0.87             5.0
# 4                    0.37             0.52             2.0
# ...                   ...              ...             ...
# 14994                 NaN              NaN             NaN
# 14995                 NaN              NaN             NaN
# 14996                 NaN              NaN             NaN
# 14997                 NaN              NaN             NaN
# 14998                 NaN              NaN             NaN
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                     157.0                 3.0            0.0   1.0
# 1                     262.0                 6.0            0.0   1.0
# ...

# %%
dummy
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(df.satisfaction_level,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='satisfaction_level'>

# %%
pd.crosstab(df.salary,df.left).plot(kind="bar")
# Out:
# <Axes: xlabel='salary'>

# %%
df.head(-4)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
latest.head(-4)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53             2.0
# 1                    0.80             0.86             5.0
# 2                    0.11             0.88             7.0
# 3                    0.72             0.87             5.0
# 4                    0.37             0.52             2.0
# ...                   ...              ...             ...
# 14990                 NaN              NaN             NaN
# 14991                 NaN              NaN             NaN
# 14992                 NaN              NaN             NaN
# 14993                 NaN              NaN             NaN
# 14994                 NaN              NaN             NaN
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                     157.0                 3.0            0.0   1.0
# 1                     262.0                 6.0            0.0   1.0
# ...

# %%
ll=latest.fillna(0)
ll
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53             2.0
# 1                    0.80             0.86             5.0
# 2                    0.11             0.88             7.0
# 3                    0.72             0.87             5.0
# 4                    0.37             0.52             2.0
# ...                   ...              ...             ...
# 14994                0.00             0.00             0.0
# 14995                0.00             0.00             0.0
# 14996                0.00             0.00             0.0
# 14997                0.00             0.00             0.0
# 14998                0.00             0.00             0.0
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                     157.0                 3.0            0.0   1.0
# 1                     262.0                 6.0            0.0   1.0
# ...

# %%
subdf=(df[["satisfaction_level","time_spend_company","promotion_last_5years","salary"]])
subdf
# Out:
#        satisfaction_level  time_spend_company  promotion_last_5years  salary
# 0                    0.38                   3                      0     low
# 1                    0.80                   6                      0  medium
# 2                    0.11                   4                      0  medium
# 3                    0.72                   5                      0     low
# 4                    0.37                   3                      0     low
# ...                   ...                 ...                    ...     ...
# 14994                0.40                   3                      0     low
# 14995                0.37                   3                      0     low
# 14996                0.37                   3                      0     low
# 14997                0.11                   4                      0     low
# 14998                0.37                   3                      0     low
#
# [14999 rows x 4 columns]

# %%
olakka=pd.get_dummies(subdf.salary,prefix="salary",dtype=int)
olakka
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
rambo=pd.concat([subdf,olakka],axis="columns")
rambo
# Out:
#        satisfaction_level  time_spend_company  promotion_last_5years  salary  \
# 0                    0.38                   3                      0     low
# 1                    0.80                   6                      0  medium
# 2                    0.11                   4                      0  medium
# 3                    0.72                   5                      0     low
# 4                    0.37                   3                      0     low
# ...                   ...                 ...                    ...     ...
# 14994                0.40                   3                      0     low
# 14995                0.37                   3                      0     low
# 14996                0.37                   3                      0     low
# 14997                0.11                   4                      0     low
# 14998                0.37                   3                      0     low
#
# ...

# %%
rambo.drop('salary',axis='columns',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 rambo.drop('salary',axis='columns',inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
rambo.drop('salary',axis='columns',inplace=True)
rambo()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 rambo.drop('salary',axis='columns',inplace=True)
#       2 rambo()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
rambo.drop("salary", axis="columns", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 rambo.drop("salary", axis="columns", inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
rambo
# Out:
#        satisfaction_level  time_spend_company  promotion_last_5years  \
# 0                    0.38                   3                      0
# 1                    0.80                   6                      0
# 2                    0.11                   4                      0
# 3                    0.72                   5                      0
# 4                    0.37                   3                      0
# ...                   ...                 ...                    ...
# 14994                0.40                   3                      0
# 14995                0.37                   3                      0
# 14996                0.37                   3                      0
# 14997                0.11                   4                      0
# 14998                0.37                   3                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
[y]
# Out:
# [0        1
#  1        1
#  2        1
#  3        1
#  4        1
#          ..
#  14994    1
#  14995    1
#  14996    1
#  14997    1
#  14998    1
#  Name: left, Length: 14999, dtype: int64]

# %%
y
# Out:
#        left
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 14994     1
# 14995     1
# 14996     1
# 14997     1
# 14998     1
#
# [14999 rows x 1 columns]

# %%
x=rambo
x
# Out:
#        satisfaction_level  time_spend_company  promotion_last_5years  \
# 0                    0.38                   3                      0
# 1                    0.80                   6                      0
# 2                    0.11                   4                      0
# 3                    0.72                   5                      0
# 4                    0.37                   3                      0
# ...                   ...                 ...                    ...
# 14994                0.40                   3                      0
# 14995                0.37                   3                      0
# 14996                0.37                   3                      0
# 14997                0.11                   4                      0
# 14998                0.37                   3                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3)

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\S7061\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\S7061\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\S7061\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1, ..., 0, 0, 0], shape=(10500,))

# %%
model.score(x_test,y_test)
# Out:
# 0.7664761904761904

# %%
y_test
# Out:
#        left
# 10894     0
# 5679      0
# 14766     1
# 11973     0
# 271       1
# ...     ...
# 11416     0
# 572       1
# 8859      0
# 7937      0
# 12199     1
#
# [10500 rows x 1 columns]
